# %%
import numpy as np

import transformers


DATASET = "../../dataset_processed/ochat.train.npz"
TOKENIZER_NAME = "imone/LLaMA_13B_with_EOT_token_8192_positions"

# %%
# Load dataset
dataset = np.load(DATASET)
# Load tokenizer
tokenizer = transformers.AutoTokenizer.from_pretrained(TOKENIZER_NAME)

# %%
# Check 1: Attention is properly masked

assert np.where(~dataset["attention_masks"], dataset["input_ids"] == tokenizer.convert_tokens_to_ids("<unk>"), True).all()

assert np.where(dataset["input_ids"] == tokenizer.convert_tokens_to_ids("<unk>"), ~dataset["attention_masks"], True).all()

# %%
# Print the supervised and unsupervised text
sample_index = 5

token_ids = dataset["input_ids"][sample_index]
labels = dataset["labels"][sample_index]

print(tokenizer.decode(token_ids[labels == -100].tolist(), spaces_between_special_tokens=False).replace("<|end_of_turn|>", "\n\n"))
print("=================")
print(tokenizer.decode(labels[labels != -100].tolist(), spaces_between_special_tokens=False).replace("<|end_of_turn|>", "\n\n"))
# Out:
# <s> Human: act as an expert pharmacologist. explain to a physician the potential interactions of the medications named here:
#
#  Wellbutrin XL to 150 mg daily for attention and concentration.
# Continue propranolol 20 mg BID for tremor and anxiety. D/c or switch to another medication if any evidence of asthma exacerbation.
# Continue Abilify 20 mg daily for mood stability
# Continue Lamictal 100 mg PO QD for mood stability
# Continue trazodone 150 mg PO QHS for sleep
# Pt takes OTC melatonin 10 mg nightly for sleep
# Patient is prescribed Cymbalta 40 mg BID for neuralgia by her PCP
# Pt also taking iron, biotin, D3, and B12"
#
#  Human: include gabapentin
#
#  Human: can wellbutrin contribute to the risk of seratonin syndrome
#
#  Human: which of these medications contribute to seratonin syndrome risk
#
#  Human: doesn't trazodone?
#
#  Human: mnemonic for seratonin syndrome
#
#  Human: make one from "SHIVERS"
#
#  Human: how to differentiate from activating symptoms of SSRI's
#
# ...
